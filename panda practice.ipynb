# %%
# %config Completer.use_jedi = False #this is command used for enable autocompletion in jupyt notebook

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\SANU'

# %%
data=pd.read_csv("seeddata.csv",header=None)

# %%
data
# Out:
#          0      1       2      3      4      5      6  7
# 0    15.26  14.84  0.8710  5.763  3.312  2.221  5.220  1
# 1    14.88  14.57  0.8811  5.554  3.333  1.018  4.956  1
# 2    14.29  14.09  0.9050  5.291  3.337  2.699  4.825  1
# 3    13.84  13.94  0.8955  5.324  3.379  2.259  4.805  1
# 4    16.14  14.99  0.9034  5.658  3.562  1.355  5.175  1
# ..     ...    ...     ...    ...    ...    ...    ... ..
# 205  12.19  13.20  0.8783  5.137  2.981  3.631  4.870  3
# 206  11.23  12.88  0.8511  5.140  2.795  4.325  5.003  3
# 207  13.20  13.66  0.8883  5.236  3.232  8.315  5.056  3
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044  3
# 209  12.30  13.34  0.8684  5.243  2.974  5.637  5.063  3
#
# [210 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['column1', 'column2', 'column2', 'column2', 'column2', 'column2',
#        'column2', 'column2'],
#       dtype='object')

# %% [markdown]
# # Adding columnn name to dataframe

# %%
data.columns=["column1","column2","column2","column2","column2","column2","column2","column2"]

# %%
data
# Out:
#      column1  column2  column2  column2  column2  column2  column2  column2
# 0      15.26    14.84   0.8710    5.763    3.312    2.221    5.220        1
# 1      14.88    14.57   0.8811    5.554    3.333    1.018    4.956        1
# 2      14.29    14.09   0.9050    5.291    3.337    2.699    4.825        1
# 3      13.84    13.94   0.8955    5.324    3.379    2.259    4.805        1
# 4      16.14    14.99   0.9034    5.658    3.562    1.355    5.175        1
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 205    12.19    13.20   0.8783    5.137    2.981    3.631    4.870        3
# 206    11.23    12.88   0.8511    5.140    2.795    4.325    5.003        3
# 207    13.20    13.66   0.8883    5.236    3.232    8.315    5.056        3
# 208    11.84    13.21   0.8521    5.175    2.836    3.598    5.044        3
# 209    12.30    13.34   0.8684    5.243    2.974    5.637    5.063        3
#
# [210 rows x 8 columns]

# %%
data.columns=["area","Perimite","compactness","length_of_kernel","width_of_kernel","asymmetry_coeficient","length_of_kernel_groove","class"]

# %%
data
# Out:
#       area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0    15.26     14.84       0.8710             5.763            3.312
# 1    14.88     14.57       0.8811             5.554            3.333
# 2    14.29     14.09       0.9050             5.291            3.337
# 3    13.84     13.94       0.8955             5.324            3.379
# 4    16.14     14.99       0.9034             5.658            3.562
# ..     ...       ...          ...               ...              ...
# 205  12.19     13.20       0.8783             5.137            2.981
# 206  11.23     12.88       0.8511             5.140            2.795
# 207  13.20     13.66       0.8883             5.236            3.232
# 208  11.84     13.21       0.8521             5.175            2.836
# 209  12.30     13.34       0.8684             5.243            2.974
#
#      asymmetry_coeficient  length_of_kernel_groove  class
# 0                   2.221                    5.220      1
# ...

# %%
data.describe()
# Out:
#              area    Perimite  compactness  length_of_kernel  width_of_kernel  \
# count  210.000000  210.000000   210.000000        210.000000       210.000000
# mean    14.847524   14.559286     0.870999          5.628533         3.258605
# std      2.909699    1.305959     0.023629          0.443063         0.377714
# min     10.590000   12.410000     0.808100          4.899000         2.630000
# 25%     12.270000   13.450000     0.856900          5.262250         2.944000
# 50%     14.355000   14.320000     0.873450          5.523500         3.237000
# 75%     17.305000   15.715000     0.887775          5.979750         3.561750
# max     21.180000   17.250000     0.918300          6.675000         4.033000
#
#        asymmetry_coeficient  length_of_kernel_groove       class
# count            210.000000               210.000000  210.000000
# mean               3.700201                 5.408071    2.000000
# std                1.503557                 0.491480    0.818448
# ...

# %%
data["area"]
# Out:
# 15.26

# %%
type(data["area"])
# Out:
# pandas.core.series.Series

# %%
data[["area","Perimite"]]
# Out:
#       area  Perimite
# 0    15.26     14.84
# 1    14.88     14.57
# 2    14.29     14.09
# 3    13.84     13.94
# 4    16.14     14.99
# ..     ...       ...
# 205  12.19     13.20
# 206  11.23     12.88
# 207  13.20     13.66
# 208  11.84     13.21
# 209  12.30     13.34
#
# [210 rows x 2 columns]

# %%
data["area"][0:4]
# Out:
# 0    15.26
# 1    14.88
# 2    14.29
# 3    13.84
# Name: area, dtype: float64

# %%
data["area"][0:5:2]
# Out:
# 0    15.26
# 2    14.29
# 4    16.14
# Name: area, dtype: float64

# %%
data["area"][0:5:3]
# Out:
# 0    15.26
# 3    13.84
# Name: area, dtype: float64

# %%
data[["area"]][0:5:2]
#output type dataframe
# Out:
#     area
# 0  15.26
# 2  14.29
# 4  16.14

# %%
data.head()
# Out:
#     area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0  15.26     14.84       0.8710             5.763            3.312
# 1  14.88     14.57       0.8811             5.554            3.333
# 2  14.29     14.09       0.9050             5.291            3.337
# 3  13.84     13.94       0.8955             5.324            3.379
# 4  16.14     14.99       0.9034             5.658            3.562
#
#    asymmetry_coeficient  length_of_kernel_groove  class
# 0                 2.221                    5.220      1
# 1                 1.018                    4.956      1
# 2                 2.699                    4.825      1
# 3                 2.259                    4.805      1
# 4                 1.355                    5.175      1

# %%
data.dtypes
# Out:
# area                       float64
# Perimite                   float64
# compactness                float64
# length_of_kernel           float64
# width_of_kernel            float64
# asymmetry_coeficient       float64
# length_of_kernel_groove    float64
# class                        int64
# dtype: object

# %%
data.dtypes!='object'
# Out:
# area                       True
# Perimite                   True
# compactness                True
# length_of_kernel           True
# width_of_kernel            True
# asymmetry_coeficient       True
# length_of_kernel_groove    True
# class                      True
# dtype: bool

# %%
[data.dtypes!='object']
# Out:
# [area                       True
#  Perimite                   True
#  compactness                True
#  length_of_kernel           True
#  width_of_kernel            True
#  asymmetry_coeficient       True
#  length_of_kernel_groove    True
#  class                      True
#  dtype: bool]

# %%
data.dtypes[data.dtypes=='object']
# Out:
# Series([], dtype: object)

# %%
data.dtypes[data.dtypes!='object']
# Out:
# area                       float64
# Perimite                   float64
# compactness                float64
# length_of_kernel           float64
# width_of_kernel            float64
# asymmetry_coeficient       float64
# length_of_kernel_groove    float64
# class                        int64
# dtype: object

# %%
data.dtypes[data.dtypes!='object'].index
# Out:
# Index(['area', 'Perimite', 'compactness', 'length_of_kernel',
#        'width_of_kernel', 'asymmetry_coeficient', 'length_of_kernel_groove',
#        'class'],
#       dtype='object')

# %%
data[data.dtypes[data.dtypes!='object'].index]
# Out:
#       area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0    15.26     14.84       0.8710             5.763            3.312
# 1    14.88     14.57       0.8811             5.554            3.333
# 2    14.29     14.09       0.9050             5.291            3.337
# 3    13.84     13.94       0.8955             5.324            3.379
# 4    16.14     14.99       0.9034             5.658            3.562
# ..     ...       ...          ...               ...              ...
# 205  12.19     13.20       0.8783             5.137            2.981
# 206  11.23     12.88       0.8511             5.140            2.795
# 207  13.20     13.66       0.8883             5.236            3.232
# 208  11.84     13.21       0.8521             5.175            2.836
# 209  12.30     13.34       0.8684             5.243            2.974
#
#      asymmetry_coeficient  length_of_kernel_groove  class
# 0                   2.221                    5.220      1
# ...

# %%
data.dtypes=='int64'
# Out:
# area                       False
# Perimite                   False
# compactness                False
# length_of_kernel           False
# width_of_kernel            False
# asymmetry_coeficient       False
# length_of_kernel_groove    False
# class                       True
# dtype: bool

# %%
data.dtypes[data.dtypes=='int64']
# Out:
# class    int64
# dtype: object

# %%
data.dtypes[data.dtypes=='int64'].index
# Out:
# Index(['class'], dtype='object')

# %%
data[data.dtypes[data.dtypes=='int64'].index]
# Out:
#      class
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 205      3
# 206      3
# 207      3
# 208      3
# 209      3
#
# [210 rows x 1 columns]

# %%
data
# Out:
#       area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0    15.26     14.84       0.8710             5.763            3.312
# 1    14.88     14.57       0.8811             5.554            3.333
# 2    14.29     14.09       0.9050             5.291            3.337
# 3    13.84     13.94       0.8955             5.324            3.379
# 4    16.14     14.99       0.9034             5.658            3.562
# ..     ...       ...          ...               ...              ...
# 205  12.19     13.20       0.8783             5.137            2.981
# 206  11.23     12.88       0.8511             5.140            2.795
# 207  13.20     13.66       0.8883             5.236            3.232
# 208  11.84     13.21       0.8521             5.175            2.836
# 209  12.30     13.34       0.8684             5.243            2.974
#
#      asymmetry_coeficient  length_of_kernel_groove  class
# 0                   2.221                    5.220      1
# ...

# %%
max(data["area"])
# Out:
# 21.18

# %%
data["area"]==max(data["area"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 205    False
# 206    False
# 207    False
# 208    False
# 209    False
# Name: area, Length: 210, dtype: bool

# %%
#fetch maximum area information
data[data["area"]==max(data["area"])]
# Out:
#      area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 88  21.18     17.21       0.8989             6.573            4.033
#
#     asymmetry_coeficient  length_of_kernel_groove  class
# 88                  5.78                    6.231      2

# %%
data
# Out:
#       area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0    15.26     14.84       0.8710             5.763            3.312
# 1    14.88     14.57       0.8811             5.554            3.333
# 2    14.29     14.09       0.9050             5.291            3.337
# 3    13.84     13.94       0.8955             5.324            3.379
# 4    16.14     14.99       0.9034             5.658            3.562
# ..     ...       ...          ...               ...              ...
# 205  12.19     13.20       0.8783             5.137            2.981
# 206  11.23     12.88       0.8511             5.140            2.795
# 207  13.20     13.66       0.8883             5.236            3.232
# 208  11.84     13.21       0.8521             5.175            2.836
# 209  12.30     13.34       0.8684             5.243            2.974
#
#      asymmetry_coeficient  length_of_kernel_groove  class
# 0                   2.221                    5.220      1
# ...

# %% [markdown]
# # fetch perimiter,compactness,class having area more or equal 14

# %%
data["area"]
# Out:
# 0      15.26
# 1      14.88
# 2      14.29
# 3      13.84
# 4      16.14
#        ...
# 205    12.19
# 206    11.23
# 207    13.20
# 208    11.84
# 209    12.30
# Name: area, Length: 210, dtype: float64

# %%
data[['area']]
# Out:
#       area
# 0    15.26
# 1    14.88
# 2    14.29
# 3    13.84
# 4    16.14
# ..     ...
# 205  12.19
# 206  11.23
# 207  13.20
# 208  11.84
# 209  12.30
#
# [210 rows x 1 columns]

# %%
data["area"]>=14
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 205    False
# 206    False
# 207    False
# 208    False
# 209    False
# Name: area, Length: 210, dtype: bool

# %%
data[data["area"]>=14]
# Out:
#       area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0    15.26     14.84       0.8710             5.763            3.312
# 1    14.88     14.57       0.8811             5.554            3.333
# 2    14.29     14.09       0.9050             5.291            3.337
# 4    16.14     14.99       0.9034             5.658            3.562
# 5    14.38     14.21       0.8951             5.386            3.312
# ..     ...       ...          ...               ...              ...
# 135  15.38     14.66       0.8990             5.477            3.465
# 136  17.36     15.76       0.8785             6.145            3.574
# 137  15.57     15.15       0.8527             5.920            3.231
# 138  15.60     15.11       0.8580             5.832            3.286
# 139  16.23     15.18       0.8850             5.872            3.472
#
#      asymmetry_coeficient  length_of_kernel_groove  class
# 0                   2.221                    5.220      1
# ...

# %%
df=data[data["area"]>=14][["area","Perimite","compactness","class"]]

# %%
df
# Out:
#       area  Perimite  compactness  class
# 0    15.26     14.84       0.8710      1
# 1    14.88     14.57       0.8811      1
# 2    14.29     14.09       0.9050      1
# 4    16.14     14.99       0.9034      1
# 5    14.38     14.21       0.8951      1
# ..     ...       ...          ...    ...
# 135  15.38     14.66       0.8990      2
# 136  17.36     15.76       0.8785      2
# 137  15.57     15.15       0.8527      2
# 138  15.60     15.11       0.8580      2
# 139  16.23     15.18       0.8850      2
#
# [116 rows x 4 columns]

# %%
df.describe()
# Out:
#              area    Perimite  compactness       class
# count  116.000000  116.000000   116.000000  116.000000
# mean    17.014914   15.533276     0.883055    1.603448
# std      2.037903    0.913277     0.015308    0.491304
# min     14.010000   14.090000     0.845200    1.000000
# 25%     15.095000   14.732500     0.872350    1.000000
# 50%     16.830000   15.530000     0.882150    2.000000
# 75%     18.857500   16.290000     0.897100    2.000000
# max     21.180000   17.250000     0.915300    2.000000

# %%
data
# Out:
#       area  Perimite  compactness  length_of_kernel  width_of_kernel  \
# 0    15.26     14.84       0.8710             5.763            3.312
# 1    14.88     14.57       0.8811             5.554            3.333
# 2    14.29     14.09       0.9050             5.291            3.337
# 3    13.84     13.94       0.8955             5.324            3.379
# 4    16.14     14.99       0.9034             5.658            3.562
# ..     ...       ...          ...               ...              ...
# 205  12.19     13.20       0.8783             5.137            2.981
# 206  11.23     12.88       0.8511             5.140            2.795
# 207  13.20     13.66       0.8883             5.236            3.232
# 208  11.84     13.21       0.8521             5.175            2.836
# 209  12.30     13.34       0.8684             5.243            2.974
#
#      asymmetry_coeficient  length_of_kernel_groove  class
# 0                   2.221                    5.220      1
# ...

# %%
data["length_of_kernel"]
# Out:
# 0      5.763
# 1      5.554
# 2      5.291
# 3      5.324
# 4      5.658
#        ...
# 205    5.137
# 206    5.140
# 207    5.236
# 208    5.175
# 209    5.243
# Name: length_of_kernel, Length: 210, dtype: float64

# %%
data[["length_of_kernel"]]
# Out:
#      length_of_kernel
# 0               5.763
# 1               5.554
# 2               5.291
# 3               5.324
# 4               5.658
# ..                ...
# 205             5.137
# 206             5.140
# 207             5.236
# 208             5.175
# 209             5.243
#
# [210 rows x 1 columns]

# %%
data[["length_of_kernel"]].describe()
# Out:
#        length_of_kernel
# count        210.000000
# mean           5.628533
# std            0.443063
# min            4.899000
# 25%            5.262250
# 50%            5.523500
# 75%            5.979750
# max            6.675000

# %%
data["length_of_kernel"]>=5.5
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 205    False
# 206    False
# 207    False
# 208    False
# 209    False
# Name: length_of_kernel, Length: 210, dtype: bool

# %%
data[data["length_of_kernel"]>=6][["length_of_kernel","area","Perimite","class"]]
# Out:
#      length_of_kernel   area  Perimite  class
# 8               6.053  16.63     15.46      1
# 70              6.191  17.63     15.98      2
# 73              6.154  19.11     16.26      2
# 74              6.017  16.82     15.51      2
# 76              6.064  17.32     15.91      2
# 77              6.579  20.71     17.23      2
# 78              6.445  18.94     16.49      2
# 81              6.006  18.72     16.19      2
# 82              6.285  20.20     16.89      2
# 83              6.384  19.57     16.74      2
# 84              6.366  19.51     16.71      2
# 85              6.173  18.27     16.09      2
# 86              6.084  18.88     16.26      2
# 87              6.549  18.98     16.66      2
# 88              6.573  21.18     17.21      2
# 89              6.450  20.88     17.05      2
# 90              6.581  20.10     16.99      2
# 91              6.172  18.76     16.20      2
# 92              6.272  18.81     16.29      2
# ...
