# %%
# %config Completer.use_jedi = False #this is command used for enable autocompletion in jupyt notebook

# %%
import pandas as pd # we can use any name instead of pd it just an alias

# %%
#'C:/Users/SANU/Desktop/car_data.xlsx'

# %%
pwd
# Out:
# 'C:\\Users\\SANU'

# %% [markdown]
# # CSV=comma seperated value

# %%
data=pd.read_csv('C:/Users/SANU/Desktop/car_data.csv')
#given path #create 
#data variable and store entire data set
# by default pandas 1st row consider as header

# %%
data
# Out:
#      buying   maint  doors persons lug_boot saftey  class
# 0      vhigh  vhigh      2       2    small    low  unacc
# 1      vhigh  vhigh      2       2    small    med  unacc
# 2      vhigh  vhigh      2       2    small   high  unacc
# 3      vhigh  vhigh      2       2      med    low  unacc
# 4      vhigh  vhigh      2       2      med    med  unacc
# ...      ...    ...    ...     ...      ...    ...    ...
# 1723     low    low  5more    more      med    med   good
# 1724     low    low  5more    more      med   high  vgood
# 1725     low    low  5more    more      big    low  unacc
# 1726     low    low  5more    more      big    med   good
# 1727     low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# # dataframe is proper tabular structure means pandas always try to convert data in dataframe

# %%
data.head() #only first 5 record by default will show
# Out:
#   buying   maint doors persons lug_boot saftey  class
# 0   vhigh  vhigh     2       2    small    low  unacc
# 1   vhigh  vhigh     2       2    small    med  unacc
# 2   vhigh  vhigh     2       2    small   high  unacc
# 3   vhigh  vhigh     2       2      med    low  unacc
# 4   vhigh  vhigh     2       2      med    med  unacc

# %%
data.head(2)
# Out:
#   buying   maint doors persons lug_boot saftey  class
# 0   vhigh  vhigh     2       2    small    low  unacc
# 1   vhigh  vhigh     2       2    small    med  unacc

# %%
data.tail() #last 5 records
# Out:
#      buying  maint  doors persons lug_boot saftey  class
# 1723     low   low  5more    more      med    med   good
# 1724     low   low  5more    more      med   high  vgood
# 1725     low   low  5more    more      big    low  unacc
# 1726     low   low  5more    more      big    med   good
# 1727     low   low  5more    more      big   high  vgood

# %%
data.tail(2)
# Out:
#      buying  maint  doors persons lug_boot saftey  class
# 1726     low   low  5more    more      big    med   good
# 1727     low   low  5more    more      big   high  vgood

# %%
df=pd.read_csv('C:/Users/SANU/Desktop/car_data.csv',header=None)
#read the file without header so it consider 1st row as data

# %%
df
# Out:
#             0      1      2        3         4       5      6
# 0     buying   maint  doors  persons  lug_boot  saftey  class
# 1       vhigh  vhigh      2        2     small     low  unacc
# 2       vhigh  vhigh      2        2     small     med  unacc
# 3       vhigh  vhigh      2        2     small    high  unacc
# 4       vhigh  vhigh      2        2       med     low  unacc
# ...       ...    ...    ...      ...       ...     ...    ...
# 1724      low    low  5more     more       med     med   good
# 1725      low    low  5more     more       med    high  vgood
# 1726      low    low  5more     more       big     low  unacc
# 1727      low    low  5more     more       big     med   good
# 1728      low    low  5more     more       big    high  vgood
#
# [1729 rows x 7 columns]

# %%
df.columns #without columns name
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
data.columns
# Out:
# Index(['buying ', 'maint', 'doors', 'persons', 'lug_boot', 'saftey', 'class'], dtype='object')

# %%
data.head()
# Out:
#   buying   maint doors persons lug_boot saftey  class
# 0   vhigh  vhigh     2       2    small    low  unacc
# 1   vhigh  vhigh     2       2    small    med  unacc
# 2   vhigh  vhigh     2       2    small   high  unacc
# 3   vhigh  vhigh     2       2      med    low  unacc
# 4   vhigh  vhigh     2       2      med    med  unacc

# %%
data['buying']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'buying'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-c365b06f7229> in <module>
# ----> 1 data['buying']
#
# ...

# %%
data['buying ']
# Out:
# 0       vhigh
# 1       vhigh
# 2       vhigh
# 3       vhigh
# 4       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: buying , Length: 1728, dtype: object

# %%
data['buying ','maint'] #it will give error
#it give error for multiple column name in single squre breaket
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('buying ', 'maint')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-bede3e6a1347> in <module>
# ...

# %%
# to solve above error 
# pass columns as list in data[]
data[['buying ','maint']]
# Out:
#      buying   maint
# 0      vhigh  vhigh
# 1      vhigh  vhigh
# 2      vhigh  vhigh
# 3      vhigh  vhigh
# 4      vhigh  vhigh
# ...      ...    ...
# 1723     low    low
# 1724     low    low
# 1725     low    low
# 1726     low    low
# 1727     low    low
#
# [1728 rows x 2 columns]

# %%
data[['buying ','maint','doors','persons','lug_boot','saftey','class']]
# Out:
#      buying   maint  doors persons lug_boot saftey  class
# 0      vhigh  vhigh      2       2    small    low  unacc
# 1      vhigh  vhigh      2       2    small    med  unacc
# 2      vhigh  vhigh      2       2    small   high  unacc
# 3      vhigh  vhigh      2       2      med    low  unacc
# 4      vhigh  vhigh      2       2      med    med  unacc
# ...      ...    ...    ...     ...      ...    ...    ...
# 1723     low    low  5more    more      med    med   good
# 1724     low    low  5more    more      med   high  vgood
# 1725     low    low  5more    more      big    low  unacc
# 1726     low    low  5more    more      big    med   good
# 1727     low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
type(data['buying ']) #type is series so give error for multiple columns name
# Out:
# pandas.core.series.Series

# %%
type(data[['buying ','maint']]) # type is dataframe so it works
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# So in pandas you can find two type of data series and data frame. So if your considering only one column and row so panda will consider it as serie.

# %%
data['maint'][10]
# Out:
# 'vhigh'

# %%
data['maint'][2:8]
# Out:
# 2    vhigh
# 3    vhigh
# 4    vhigh
# 5    vhigh
# 6    vhigh
# 7    vhigh
# Name: maint, dtype: object

# %%
# looking for all data at even position
data['buying '][0::2]
# Out:
# 0       vhigh
# 2       vhigh
# 4       vhigh
# 6       vhigh
# 8       vhigh
#         ...
# 1718      low
# 1720      low
# 1722      low
# 1724      low
# 1726      low
# Name: buying , Length: 864, dtype: object

# %%
data[['buying ']]
#see output looking like dataframe
# Out:
#      buying
# 0      vhigh
# 1      vhigh
# 2      vhigh
# 3      vhigh
# 4      vhigh
# ...      ...
# 1723     low
# 1724     low
# 1725     low
# 1726     low
# 1727     low
#
# [1728 rows x 1 columns]

# %%
data[['buying ']][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-76b97ef2949c> in <module>
# ----> 1 data[['buying ']][0]
#
# ...

# %% [markdown]
# # Means indexing is not support in data frame but slice operation support in dataframe (see below code) but  we can try to achieve even that particular pard using log and ilong inbuilt function.

# %%
data[['buying ']][0:3] # see now it working because of slicing opertion
# Out:
#   buying
# 0   vhigh
# 1   vhigh
# 2   vhigh

# %%
data=pd.read_csv('car.data') #you can read data if seperator is change it may ne @/#/$/%/* etc...

# %%
data
# Out:
#         vhigh@vhigh@2@2@small@low@unacc
# 0       vhigh@vhigh@2@2@small@med@unacc
# 1      vhigh@vhigh@2@2@small@high@unacc
# 2         vhigh@vhigh@2@2@med@low@unacc
# 3         vhigh@vhigh@2@2@med@med@unacc
# 4        vhigh@vhigh@2@2@med@high@unacc
# ...                                 ...
# 1722    low@low@5more@more@med@med@good
# 1723  low@low@5more@more@med@high@vgood
# 1724   low@low@5more@more@big@low@unacc
# 1725    low@low@5more@more@big@med@good
# 1726  low@low@5more@more@big@high@vgood
#
# [1727 rows x 1 columns]

# %%
#change seperator 
data=pd.read_csv('car.data',sep='@')

# %%
#means csv is not mean seperte data only by " , " comma it may be any seprator

# %%
data
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
# lets try to read a file without seperator 
data=pd.read_csv('car_tab.data')

# %%
data
# Out:
#         vhigh\tvhigh\t2\t2\tsmall\tlow\tunacc
# 0       vhigh\tvhigh\t2\t2\tsmall\tmed\tunacc
# 1      vhigh\tvhigh\t2\t2\tsmall\thigh\tunacc
# 2         vhigh\tvhigh\t2\t2\tmed\tlow\tunacc
# 3         vhigh\tvhigh\t2\t2\tmed\tmed\tunacc
# 4        vhigh\tvhigh\t2\t2\tmed\thigh\tunacc
# ...                                       ...
# 1722    low\tlow\t5more\tmore\tmed\tmed\tgood
# 1723  low\tlow\t5more\tmore\tmed\thigh\tvgood
# 1724   low\tlow\t5more\tmore\tbig\tlow\tunacc
# 1725    low\tlow\t5more\tmore\tbig\tmed\tgood
# 1726  low\tlow\t5more\tmore\tbig\thigh\tvgood
#
# [1727 rows x 1 columns]

# %%
data=pd.read_csv('car_tab.data',sep='\t')

# %%
data
# Out:
#         vhigh\tvhigh\t2\t2\tsmall\tlow\tunacc
# 0       vhigh\tvhigh\t2\t2\tsmall\tmed\tunacc
# 1      vhigh\tvhigh\t2\t2\tsmall\thigh\tunacc
# 2         vhigh\tvhigh\t2\t2\tmed\tlow\tunacc
# 3         vhigh\tvhigh\t2\t2\tmed\tmed\tunacc
# 4        vhigh\tvhigh\t2\t2\tmed\thigh\tunacc
# ...                                       ...
# 1722    low\tlow\t5more\tmore\tmed\tmed\tgood
# 1723  low\tlow\t5more\tmore\tmed\thigh\tvgood
# 1724   low\tlow\t5more\tmore\tbig\tlow\tunacc
# 1725    low\tlow\t5more\tmore\tbig\tmed\tgood
# 1726  low\tlow\t5more\tmore\tbig\thigh\tvgood
#
# [1727 rows x 1 columns]

# %% [markdown]
# # read out excel sheet

# %%
pwd
# Out:
# 'C:\\Users\\SANU'

# %%
# %config Completer.use_jedi = False #this is command used for enable autocompletion in jupyt notebook

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# trio 0.12.1 has requirement cffi>=1.12; os_name == "nt", but you'll have cffi 1.11.5 which is incompatible.
# httpcore 0.13.7 has requirement h11<0.13,>=0.11, but you'll have h11 0.8.1 which is incompatible.
# cryptography 3.3.1 has requirement cffi>=1.12, but you'll have cffi 1.11.5 which is incompatible.
# anyio 3.3.2 has requirement idna>=2.8, but you'll have idna 2.7 which is incompatible.
# You are using pip version 10.0.1, however version 21.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
pip install xlrd==1.2.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# trio 0.12.1 has requirement cffi>=1.12; os_name == "nt", but you'll have cffi 1.11.5 which is incompatible.
# httpcore 0.13.7 has requirement h11<0.13,>=0.11, but you'll have h11 0.8.1 which is incompatible.
# cryptography 3.3.1 has requirement cffi>=1.12, but you'll have cffi 1.11.5 which is incompatible.
# anyio 3.3.2 has requirement idna>=2.8, but you'll have idna 2.7 which is incompatible.
# You are using pip version 10.0.1, however version 21.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# trio 0.12.1 has requirement cffi>=1.12; os_name == "nt", but you'll have cffi 1.11.5 which is incompatible.
# httpcore 0.13.7 has requirement h11<0.13,>=0.11, but you'll have h11 0.8.1 which is incompatible.
# cryptography 3.3.1 has requirement cffi>=1.12, but you'll have cffi 1.11.5 which is incompatible.
# anyio 3.3.2 has requirement idna>=2.8, but you'll have idna 2.7 which is incompatible.
# You are using pip version 10.0.1, however version 21.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
tsdata=pd.read_excel('C:/Users/SANU/Desktop/time_series.xlsx')

# %%
pd.read_excel('time_series.xlsx')
# Out:
#      year   month  tea, kolkata price ($/kg)
# 0     2010      1                   2.437718
# 1     2010      2                   2.294726
# 2     2010      3                   1.742236
# 3     2010      4                   2.453346
# 4     2010      5                   2.847987
# ..     ...    ...                        ...
# 127   2020      8                   4.073011
# 128   2020      9                   3.856840
# 129   2020     10                   3.504758
# 130   2020     11                   2.946539
# 131   2020     12                   2.595829
#
# [132 rows x 3 columns]

# %%
pd._version
# Out:
# <module 'pandas._version' from 'C:\\Users\\SANU\\Miniconda3\\lib\\site-packages\\pandas\\_version.py'>

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
pd.read_excel('car_data.xlsx')
# Out:
#      buying   maint  doors persons lug_boot saftey  class
# 0      vhigh  vhigh      2       2    small    low  unacc
# 1      vhigh  vhigh      2       2    small    med  unacc
# 2      vhigh  vhigh      2       2    small   high  unacc
# 3      vhigh  vhigh      2       2      med    low  unacc
# 4      vhigh  vhigh      2       2      med    med  unacc
# ...      ...    ...    ...     ...      ...    ...    ...
# 1723     low    low  5more    more      med    med   good
# 1724     low    low  5more    more      med   high  vgood
# 1725     low    low  5more    more      big    low  unacc
# 1726     low    low  5more    more      big    med   good
# 1727     low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
type(tsdata)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # How to read different different sheet form single csv or xl files

# %%
pd.read_excel('car_data.xlsx')
# Out:
#      buying   maint  doors persons lug_boot saftey  class
# 0      vhigh  vhigh      2       2    small    low  unacc
# 1      vhigh  vhigh      2       2    small    med  unacc
# 2      vhigh  vhigh      2       2    small   high  unacc
# 3      vhigh  vhigh      2       2      med    low  unacc
# 4      vhigh  vhigh      2       2      med    med  unacc
# ...      ...    ...    ...     ...      ...    ...    ...
# 1723     low    low  5more    more      med    med   good
# 1724     low    low  5more    more      med   high  vgood
# 1725     low    low  5more    more      big    low  unacc
# 1726     low    low  5more    more      big    med   good
# 1727     low    low  5more    more      big   high  vgood
#
# [1728 rows x 7 columns]

# %%
pd.read_excel('time_series.xlsx')
# Out:
#      year   month  tea, kolkata price ($/kg)
# 0     2010      1                   2.437718
# 1     2010      2                   2.294726
# 2     2010      3                   1.742236
# 3     2010      4                   2.453346
# 4     2010      5                   2.847987
# ..     ...    ...                        ...
# 127   2020      8                   4.073011
# 128   2020      9                   3.856840
# 129   2020     10                   3.504758
# 130   2020     11                   2.946539
# 131   2020     12                   2.595829
#
# [132 rows x 3 columns]

# %% [markdown]
# # using sheet_name='Sheet2' argument

# %%
pd.read_excel('time_series.xlsx',sheet_name='Sheet2')
# Out:
#    2017.000000  6.000000     2.625313
# 0         2017            7     2.831651
# 1         2017            8     2.766833
# 2         2017            9     2.617789
# 3         2017           10     2.635007
# 4         2017           11     2.613928
# 5         2017           12     2.496444

# %%
df4=pd.read_excel('time_series.xlsx',sheet_name='abc')

# %%
df4
# Out:
#    2015.00000  3.00000     1.42405
# 0        2015           4    2.126130
# 1        2015           5    2.595660
# 2        2015           6    2.712210
# 3        2015           7    2.856930
# 4        2015           8    2.797289
# 5        2015           9    2.592161
# 6        2015          10    2.537123
# 7        2015          11    2.489656
# 8        2015          12    2.450543

# %%
df4.head()
# Out:
#    2015.00000  3.00000     1.42405
# 0        2015           4    2.126130
# 1        2015           5    2.595660
# 2        2015           6    2.712210
# 3        2015           7    2.856930
# 4        2015           8    2.797289

# %%
df4.head(2)
# Out:
#    2015.00000  3.00000     1.42405
# 0        2015           4     2.12613
# 1        2015           5     2.59566

# %%
df4.tail()
# Out:
#    2015.00000  3.00000     1.42405
# 4        2015           8    2.797289
# 5        2015           9    2.592161
# 6        2015          10    2.537123
# 7        2015          11    2.489656
# 8        2015          12    2.450543

# %%
df4.tail(1)
# Out:
#    2015.00000  3.00000     1.42405
# 8        2015          12    2.450543

# %%
df4.columns
# Out:
# Float64Index([2015.0, 3.0, 1.42405004206269], dtype='float64')

# %%
#remove a header 
df4=pd.read_excel('time_series.xlsx',sheet_name='abc',header=0)

# %%
df4
# Out:
#    2015.00000  3.00000     1.42405
# 0        2015           4    2.126130
# 1        2015           5    2.595660
# 2        2015           6    2.712210
# 3        2015           7    2.856930
# 4        2015           8    2.797289
# 5        2015           9    2.592161
# 6        2015          10    2.537123
# 7        2015          11    2.489656
# 8        2015          12    2.450543

# %% [markdown]
# # how to convert csv to excel

# %%
df4.to_csv('test.csv')
#it will store 'C:\Users\SANU'

# %%
pwd
# Out:
# 'C:\\Users\\SANU'

# %% [markdown]
# # Read data directly using URL (in GitHub using raw link of data)

# %%
df5=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/all_stocks_5yr.csv')

# %%
df5
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
df5.describe()
# Out:
#                 open           high            low          close  \
# count  619029.000000  619032.000000  619032.000000  619040.000000
# mean       83.023334      83.778311      82.256096      83.043763
# std        97.378769      98.207519      96.507421      97.389748
# min         1.620000       1.690000       1.500000       1.590000
# 25%        40.220000      40.620000      39.830000      40.245000
# 50%        62.590000      63.150000      62.020000      62.620000
# 75%        94.370000      95.180000      93.540000      94.410000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  6.190400e+05
# mean   4.321823e+06
# std    8.693610e+06
# min    0.000000e+00
# 25%    1.070320e+06
# 50%    2.082094e+06
# 75%    4.284509e+06
# max    6.182376e+08

# %%
df6=pd.read_csv('https://raw.githubusercontent.com/datasets/covid-19/main/data/worldwide-aggregate.csv')

# %%
df6
# Out:
#            Date  Confirmed  Recovered   Deaths  Increase rate
# 0    2020-01-22        557         30       17            NaN
# 1    2020-01-23        655         32       18      17.594255
# 2    2020-01-24        941         39       26      43.664122
# 3    2020-01-25       1434         42       42      52.391073
# 4    2020-01-26       2118         56       56      47.698745
# ..          ...        ...        ...      ...            ...
# 625  2021-10-08  237249330          0  4842432       0.202162
# 626  2021-10-09  237578163          0  4847106       0.138602
# 627  2021-10-10  237878832          0  4851586       0.126556
# 628  2021-10-11  238272207          0  4857420       0.165368
# 629  2021-10-12  238688934          0  4865393       0.174895
#
# [630 rows x 5 columns]

# %%
df6.describe()
# Out:
#           Confirmed     Recovered        Deaths  Increase rate
# count  6.300000e+02  6.300000e+02  6.300000e+02     629.000000
# mean   8.552112e+07  3.728803e+07  1.950039e+06       2.226795
# std    7.812208e+07  4.074961e+07  1.573980e+06       6.151629
# min    5.570000e+02  0.000000e+00  1.700000e+01       0.124457
# 25%    1.000511e+07  6.284965e+05  5.242488e+05       0.347493
# 50%    6.436702e+07  2.212479e+07  1.544253e+06       0.851336
# 75%    1.575524e+08  6.437467e+07  3.391731e+06       1.689874
# max    2.386889e+08  1.308991e+08  4.865393e+06      90.570550

# %% [markdown]
# # tell me data type of evey columns

# %%
df6.dtypes
#now you can see below result 
#objec mean string type
# Out:
# Date              object
# Confirmed          int64
# Recovered          int64
# Deaths             int64
# Increase rate    float64
# dtype: object

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           630 non-null    object
#  1   Confirmed      630 non-null    int64
#  2   Recovered      630 non-null    int64
#  3   Deaths         630 non-null    int64
#  4   Increase rate  629 non-null    float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 24.7+ KB

# %% [markdown]
# # Read data from HTML page

# %%
import pandas as pd

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %% [markdown]
# # It did not read all data from html means it avoid to some tabular data set and not in proper or sturcture  formate you can see above result but my requirement is to read only read all tabular data sets.

# %%
df7=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
l=[1,2,4,5]

# %%
l[0]
# Out:
# 1

# %%
len(df7)
#len=1 means only one dataframe inside a list df7
# Out:
# 1

# %%
type(l)
# Out:
# list

# %%
type(df7)
# Out:
# list

# %%
df7[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df7[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df7[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
#store data inside in local memory
df7[0].to_csv('test_1')

# %%
pwd
# Out:
# 'C:\\Users\\SANU'

# %%
df8=df7[0]

# %%
df8.describe()
# Out:
#          Rk  Player  Pos  Age   Tm    G   GS   MP   FG  FGA  ...   FT%  ORB  \
# count   675     675  675  675  675  675  675  675  675  675  ...   650  675
# unique  493     493   12   21   32   84   81  557  327  458  ...   275  165
# top      Rk  Player   SG   23  TOT   82    0   MP   FG  FGA  ...  .500    1
# freq     24      24  143   86   76   27  179   24   24   24  ...    29   30
#
#         DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# count   675  675  675  675  675  675  675  675
# unique  293  350  249  119   98  177  214  463
# top     DRB  TRB  AST    0    0  TOV   PF  PTS
# freq     24   24   24   29   88   24   24   24
#
# [4 rows x 30 columns]

# %%
df8.describe().to_csv('test_1_describe')

# %%
df8.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      675 non-null    object
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     675 non-null    object
#  4   Tm      675 non-null    object
#  5   G       675 non-null    object
#  6   GS      675 non-null    object
#  7   MP      675 non-null    object
#  8   FG      675 non-null    object
#  9   FGA     675 non-null    object
#  10  FG%     673 non-null    object
#  11  3P      675 non-null    object
#  12  3PA     675 non-null    object
#  13  3P%     594 non-null    object
#  14  2P      675 non-null    object
#  15  2PA     675 non-null    object
#  16  2P%     671 non-null    object
#  17  eFG%    673 non-null    object
#  18  FT      675 non-null    object
#  19  FTA     675 non-null    object
#  20  FT%     650 non-null    object
# ...

# %% [markdown]
# # pandas profiling

# %%
! pip install pandas-profiling
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/b8/bb/7d1a8523711c7022601d17a8449b822dc5ffaf272692d3538771b0538631/pandas_profiling-3.1.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/66/7a/9f3a49dea61e98ac8bd3b6b619da4fcb59053232a6e11e9e865dab7c16e0/PyYAML-5.4.1-cp37-cp37m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/5b/94/bfe9a0f68152118e805bdada61eb1259cd703f9d4bab747495aacce7af1d/multimethod-1.6-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/b3/e7/fcd59e12169de19f0131ff2812077f964c6b960e7c09804d30a7bf2ab461/htmlmin-0.1.12.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/66/00/166b2beb8046f06b77a2bf2c1dafeb52eff608f7dd420c767d5f3ce36ef5/visions-0.7.4-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/84/6a/3b9902f79b81b4f67b6e7497f3d9c9f1e6bd7a7f4e93ccd6bc0aa8f81282/pydantic-1.8.2-cp37-cp37m-win_amd64.whl
# ...

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df10=pd.read_excel('car_data.xlsx')

# %%
 ProfileReport(df10, title="Pandas Profiling Report")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     416     def _repr_html_(self) -> None:
#     417         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418         self.to_notebook_iframe()
#     419
#     420     def __repr__(self) -> str:
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in to_notebook_iframe(self)
#     396         with warnings.catch_warnings():
#     397             warnings.simplefilter("ignore")
# ...

# %%
profile
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     416     def _repr_html_(self) -> None:
#     417         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418         self.to_notebook_iframe()
#     419
#     420     def __repr__(self) -> str:
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in to_notebook_iframe(self)
#     396         with warnings.catch_warnings():
#     397             warnings.simplefilter("ignore")
# ...

# %%
df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x000001D88695BE18>
# Traceback (most recent call last):
#   File "C:\Users\SANU\Miniconda3\lib\site-packages\tqdm\std.py", line 1134, in __del__
#     self.close()
#   File "C:\Users\SANU\Miniconda3\lib\site-packages\tqdm\notebook.py", line 280, in close
#     self.disp(bar_style='danger')
# AttributeError: 'tqdm' object has no attribute 'disp'

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# %%
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-155-1055f09e4b48> in <module>
# ----> 1 profile.to_widgets()
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in to_widgets(self)
#     412         from IPython.core.display import display
#     413
# --> 414         display(self.widgets)
#     415
#     416     def _repr_html_(self) -> None:
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in widgets(self)
#     195     def widgets(self) -> Renderable:
#     196         if self._widgets is None:
# --> 197             self._widgets = self._render_widgets()
#     198         return self._widgets
#     199
#
# ~\Miniconda3\lib\site-packages\pandas_profiling\profile_report.py in _render_widgets(self)
#     313         from pandas_profiling.report.presentation.flavours import WidgetReport
#     314
# ...
