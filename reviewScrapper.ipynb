# %%
# %config Completer.use_jedi = False #this is command used for enable autocompletion in jupyt notebook

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\SANU\Miniconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\SANU\Miniconda3\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
#first We have to reach out to the web page
flipkart_url = "https://www.flipkart.com/search?q="+"mobile"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=mobile'

# %%
#Open the URL url, which can be either a string or a Request object.
uClient = uReq(flipkart_url)

# %%
uClient

# %%
flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
# beautifulsoap (bs) library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkart_html.title
# Out:
# <title>Mobile- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_2kHMtA"}) # seacrhing for appropriate tag to redirect to the product link

# %%
bigboxes
# Out:
# [<div class="_2kHMtA"><div class="_2tfzpE"><span>Ad</span></div><a class="_1fQZEK" href="/eunity-u1-pearl/p/itmdc00d658c4eb9?pid=MOBG9MUVB7H472D6&amp;lid=LSTMOBG9MUVB7H472D6USIWVE&amp;marketplace=FLIPKART&amp;q=mobile&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=en_Ow3YMvwKp2%2BLahgowSteOhX01O29HeKyeBm9eAN4HB85n5ARn%2BB1GkeEFoFqnqwQil2L8ATWrNoouKkmMbo6Rg%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=t5jwexfqo00000001639834196176&amp;qH=532c28d5412dd75b" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Eunity U1 Pearl" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kx3l0nk0/mobile/b/c/7/u1-pearl-u1-eunity-original-imag9muubhpg3vfy.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label>
# ...

# %%
len(bigboxes)
# Out:
# 24

# %%
box=bigboxes[0]

# %%
box.div
# Out:
# <div class="_2tfzpE"><span>Ad</span></div>

# %%
box.div.div

# %%
box.a['href']
# Out:
# '/eunity-u1-pearl/p/itmdc00d658c4eb9?pid=MOBG9MUVB7H472D6&lid=LSTMOBG9MUVB7H472D6USIWVE&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=en_Ow3YMvwKp2%2BLahgowSteOhX01O29HeKyeBm9eAN4HB85n5ARn%2BB1GkeEFoFqnqwQil2L8ATWrNoouKkmMbo6Rg%3D%3D&ppt=None&ppn=None&ssid=t5jwexfqo00000001639834196176&qH=532c28d5412dd75b'

# %%
productLink = "https://www.flipkart.com" + box.a['href'] # extracting the actual product link

# %%
productLink
# Out:
# 'https://www.flipkart.com/eunity-u1-pearl/p/itmdc00d658c4eb9?pid=MOBG9MUVB7H472D6&lid=LSTMOBG9MUVB7H472D6USIWVE&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=en_Ow3YMvwKp2%2BLahgowSteOhX01O29HeKyeBm9eAN4HB85n5ARn%2BB1GkeEFoFqnqwQil2L8ATWrNoouKkmMbo6Rg%3D%3D&ppt=None&ppn=None&ssid=t5jwexfqo00000001639834196176&qH=532c28d5412dd75b'

# %%
prodRes = requests.get(productLink)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_3k-BhJ"})

# %%
prod_html.findAll('div', {"class": "_3k-BhJ"})
# Out:
# [<div class="_3k-BhJ"><div class="flxcaE">General</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Handset, 1 Battery, 1 Charger</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1 Pearl</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Black</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Feature Phones</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">SIM Type</td><td class="URwL2w col col-9-12"><ul><li class
# ...

# %%
commentboxes
# Out:
# [<div class="_3k-BhJ"><div class="flxcaE">General</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Handset, 1 Battery, 1 Charger</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1 Pearl</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Black</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Feature Phones</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">SIM Type</td><td class="URwL2w col col-9-12"><ul><li class
# ...

# %%
len(commentboxes)
# Out:
# 9

# %%
commentboxes[0]
# Out:
# <div class="_3k-BhJ"><div class="flxcaE">General</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Handset, 1 Battery, 1 Charger</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1 Pearl</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Black</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Feature Phones</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">SIM Type</td><td class="URwL2w col col-9-12"><ul><li class=
# ...

# %%
commentboxes[0].table
# Out:
# <table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Handset, 1 Battery, 1 Charger</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1 Pearl</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Black</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Feature Phones</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">SIM Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Dual Sim</li></ul></td></tr><tr class="_1s_S
# ...

# %%
commentboxes[0].table.find_all('tr')
# Out:
# [<tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1 Handset, 1 Battery, 1 Charger</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">U1 Pearl</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Black</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Feature Phones</li></ul></td></tr>,
#  <tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">SIM Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Dual Sim</li></ul></td></tr>,
# ...

# %%
commentboxes[2]
# Out:
# <div class="_3k-BhJ"><div class="flxcaE">Os &amp; Processor Features</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Primary Clock Speed</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">1.77 MHz</li></ul></td></tr></tbody></table></div>

# %%
commentboxes[1]
# Out:
# <div class="_3k-BhJ"><div class="flxcaE">Display Features</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Display Size</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">4.57 cm (1.8 inch)</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Resolution</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">176x220$$pixel</li></ul></td></tr></tbody></table></div>

# %%
commentboxes[1].find_all('div',{'class':""})
# Out:
# [<div><div class="">mobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">mobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.</div>,
#  <div></div>,
# ...

# %%
commentboxes[1].div.div.div.find_all('div',{'class':""})
# Out:
# [<div><div class="">mobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">mobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.</div>,
#  <div></div>]

# %%
commentboxes[1].div.div.div.find_all('div',{'class':""})[0].text
# Out:
# 'mobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.READ MORE'

# %%
commentboxes[1].div.div.div.text
# Out:
# '4Very Goodmobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.READ MOREAjith R NairCertified Buyer, Idukki District2months ago1485255PermalinkReport Abuse'

# %%
commentboxes[1].div.div.div.text
# Out:
# '4Very Goodmobile is good. overall design and build is nice and feel good to hold on to it. camera is above average better compere to other phones in this segment. display bright and smooth. speaker is okay. os there is bloat some of em we can remove but not all, the one bad thing is need to accept terms and conditions before using each action like app search, launcher etc there is no options to opt out.READ MOREAjith R NairCertified Buyer, Idukki District2months ago1485255PermalinkReport Abuse'
